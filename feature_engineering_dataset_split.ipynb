# %% [markdown]
# # Feature Engineering and train, dev, val split

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import os
from sklearn.model_selection import train_test_split 
from scipy.stats import mode
from sklearn.metrics import mean_squared_error 

# %matplotlib inline
import gc #garbage collector interface

import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Feature Engineering on the Historical and New Merchants Datasets

# %% [markdown]
# read Historical Transactions dataset

# %%
hist_df = pd.read_csv("data/historical_transactions.csv")
hist_df.head()
# Out:
#   authorized_flag          card_id  city_id category_1  installments  \
# 0               Y  C_ID_4e6213e9bc       88          N             0
# 1               Y  C_ID_4e6213e9bc       88          N             0
# 2               Y  C_ID_4e6213e9bc       88          N             0
# 3               Y  C_ID_4e6213e9bc       88          N             0
# 4               Y  C_ID_4e6213e9bc       88          N             0
#
#   category_3  merchant_category_id      merchant_id  month_lag  \
# 0          A                    80  M_ID_e020e9b302         -8
# 1          A                   367  M_ID_86ec983688         -7
# 2          A                    80  M_ID_979ed661fc         -6
# 3          A                   560  M_ID_e6d5ae8ea6         -5
# 4          A                    80  M_ID_e020e9b302        -11
#
#    purchase_amount        purchase_date  category_2  state_id  subsector_id
# 0        -0.703331  2017-06-25 15:33:07         1.0        16            37
# 1        -0.733128  2017-07-15 12:10:45         1.0        16            16
# 2        -0.720386  2017-08-09 22:04:29         1.0        16            37
# 3        -0.735352  2017-09-02 10:06:26         1.0        16            34
# 4        -0.722865  2017-03-10 01:14:19         1.0        16            37

# %%
hist_df.columns
# Out:
# Index(['authorized_flag', 'card_id', 'city_id', 'category_1', 'installments',
#        'category_3', 'merchant_category_id', 'merchant_id', 'month_lag',
#        'purchase_amount', 'purchase_date', 'category_2', 'state_id',
#        'subsector_id'],
#       dtype='object')

# %% [markdown]
# read new merchants dataset

# %%
new_merchant_df = pd.read_csv("data/new_merchant_transactions.csv")
new_merchant_df.head()
# Out:
#   authorized_flag          card_id  city_id category_1  installments  \
# 0               Y  C_ID_415bb3a509      107          N             1
# 1               Y  C_ID_415bb3a509      140          N             1
# 2               Y  C_ID_415bb3a509      330          N             1
# 3               Y  C_ID_415bb3a509       -1          Y             1
# 4               Y  C_ID_ef55cf8d4b       -1          Y             1
#
#   category_3  merchant_category_id      merchant_id  month_lag  \
# 0          B                   307  M_ID_b0c793002c          1
# 1          B                   307  M_ID_88920c89e8          1
# 2          B                   507  M_ID_ad5237ef6b          2
# 3          B                   661  M_ID_9e84cda3b1          1
# 4          B                   166  M_ID_3c86fa3831          1
#
#    purchase_amount        purchase_date  category_2  state_id  subsector_id
# 0        -0.557574  2018-03-11 14:57:36         1.0         9            19
# 1        -0.569580  2018-03-19 18:53:37         1.0         9            19
# 2        -0.551037  2018-04-26 14:08:44         1.0         9            14
# 3        -0.671925  2018-03-07 09:43:21         NaN        -1             8
# 4        -0.659904  2018-03-22 21:07:53         NaN        -1            29

# %%
new_merchant_df.columns
# Out:
# Index(['authorized_flag', 'card_id', 'city_id', 'category_1', 'installments',
#        'category_3', 'merchant_category_id', 'merchant_id', 'month_lag',
#        'purchase_amount', 'purchase_date', 'category_2', 'state_id',
#        'subsector_id'],
#       dtype='object')

# %% [markdown]
# define simple function to compute the [mode](https://en.wikipedia.org/wiki/Mode_(statistics)) of an array-like structure. The default scipy function returns both the value and the occurance absolute frequence.

# %%
def mod(arr):
    return mode(arr)[0][0]

# %% [markdown]
# We want to aggregate different function to different column of the dataframe. We construct three dictionaries with the following structure:
# ```python
# {col_to_be_applied: {result_col_name: function}}
# ```

# %%
aggregationDictHist = {'card_id':{'hist_transactions_count':'count'},
        'merchant_category_id':{'hist_most_frequent_merchant_cat':mod},
                       'subsector_id':{'hist_most_frequent_subsector':mod},
        'city_id':{'hist_most_frequent_city':mod}, 'state_id':{'hist_most_frequent_state':mod},
        'month_lag':{'hist_min_month_lag':'min'},'purchase_amount':{'hist_max_purchase_amount':'max'}}

# %%
aggregationDictNew = {'card_id':{'new_transactions_count':'count'},
        'merchant_category_id':{'new_most_frequent_merchant_cat':mod},
                       'subsector_id':{'new_most_frequent_subsector':mod},
        'city_id':{'new_most_frequent_city':mod}, 'state_id':{'new_most_frequent_state':mod},
        'month_lag':{'new_min_month_lag':'min'},'purchase_amount':{'new_max_purchase_amount':'max'}}

# %% [markdown]
# apply aggregated functions to historical df

# %%
hist_grouped = hist_df[['card_id','merchant_category_id','subsector_id','city_id',
                'state_id','month_lag','purchase_amount']].groupby('card_id').agg(aggregationDictHist)
hist_grouped.columns = hist_grouped.columns.droplevel(0)

# %%
hist_grouped.head()
# Out:
#                  hist_transactions_count  hist_most_frequent_merchant_cat  \
# card_id
# C_ID_00007093c1                      149                              307
# C_ID_0001238066                      123                              307
# C_ID_0001506ef0                       66                              705
# C_ID_0001793786                      216                              278
# C_ID_000183fdda                      144                              367
#
#                  hist_most_frequent_subsector  hist_most_frequent_city  \
# card_id
# C_ID_00007093c1                            19                      244
# C_ID_0001238066                            19                      314
# C_ID_0001506ef0                            33                      137
# C_ID_0001793786                            37                      179
# C_ID_000183fdda                            16                      161
#
#                  hist_most_frequent_state  hist_min_month_lag  \
# card_id
# C_ID_00007093c1                         2                 -12
# C_ID_0001238066                         9                  -5
# C_ID_0001506ef0                        19                 -13
# C_ID_0001793786                        -1                  -9
# C_ID_000183fdda                         3                  -6
#
#                  hist_max_purchase_amount
# card_id
# C_ID_00007093c1                  1.507069
# C_ID_0001238066                  0.768095
# C_ID_0001506ef0                  1.493545
# C_ID_0001793786                  4.554145
# C_ID_000183fdda                  2.764788

# %%
#in hist dataset
totalH = hist_grouped.isnull().sum().sort_values(ascending = False)
percentH = (hist_grouped.isnull().sum()/hist_grouped.isnull().count()*100).sort_values(ascending = False)
missing_data_h  = pd.concat([totalH, percentH], axis=1, keys=['Total', 'Percent']) # axis = 1 because it concatenates 2 columns, not rows
missing_data_h.head(2)
# Out:
#                           Total  Percent
# hist_max_purchase_amount      0      0.0
# hist_min_month_lag            0      0.0

# %% [markdown]
# Apply aggregated functions in the new merchants dataset:

# %%
new_merchant_grouped = new_merchant_df[['card_id','merchant_category_id','subsector_id','city_id',
                'state_id','month_lag','purchase_amount']].groupby('card_id').agg(aggregationDictNew)
new_merchant_grouped.columns = new_merchant_grouped.columns.droplevel(0)

# %%
new_merchant_grouped.head()
# Out:
#                  new_transactions_count  new_most_frequent_merchant_cat  \
# card_id
# C_ID_00007093c1                       2                             222
# C_ID_0001238066                      26                             278
# C_ID_0001506ef0                       2                             360
# C_ID_0001793786                      31                             278
# C_ID_000183fdda                      11                             367
#
#                  new_most_frequent_subsector  new_most_frequent_city  \
# card_id
# C_ID_00007093c1                           21                      69
# C_ID_0001238066                           37                     314
# C_ID_0001506ef0                           33                     137
# C_ID_0001793786                           37                      69
# C_ID_000183fdda                           16                     161
#
#                  new_most_frequent_state  new_min_month_lag  \
# card_id
# C_ID_00007093c1                        2                  2
# C_ID_0001238066                        9                  1
# C_ID_0001506ef0                       19                  1
# C_ID_0001793786                        9                  1
# C_ID_000183fdda                        3                  1
#
#                  new_max_purchase_amount
# card_id
# C_ID_00007093c1                -0.656749
# C_ID_0001238066                -0.078318
# C_ID_0001506ef0                -0.715352
# C_ID_0001793786                 3.129932
# C_ID_000183fdda                -0.107680

# %%
totalN = new_merchant_grouped.isnull().sum().sort_values(ascending = False)
percentN = (new_merchant_grouped.isnull().sum()/new_merchant_grouped.isnull().count()*100).sort_values(ascending = False)
missing_data_n  = pd.concat([totalN, percentN], axis=1, keys=['Total', 'Percent']) # axis = 1 because it concatenates 2 columns, not rows
missing_data_n.head(2)
# Out:
#                          Total  Percent
# new_max_purchase_amount      0      0.0
# new_min_month_lag            0      0.0

# %% [markdown]
# ## Train-val-dev split

# %% [markdown]
# We want to split the training set into train, dev, val, following a 60-20-20 splitting

# %%
train_df = pd.read_csv(os.path.join("data","train.csv"), 
                       parse_dates = ["first_active_month"]) # parse_dates param in order to have a correct date format

# %%
train_df.head(3)
# Out:
#   first_active_month          card_id  feature_1  feature_2  feature_3  \
# 0         2017-06-01  C_ID_92a2005557          5          2          1
# 1         2017-01-01  C_ID_3d0044924f          4          1          0
# 2         2016-08-01  C_ID_d639edf6cd          2          2          0
#
#      target
# 0 -0.820283
# 1  0.392913
# 2  0.688056

# %%
test_df = pd.read_csv("data/test.csv", parse_dates = ["first_active_month"])

# %%
len(train_df)
# Out:
# 201917

# %% [markdown]
# merge the hist and new merchants features to the train_df

# %%
train_df_feats = hist_grouped.reset_index().merge(new_merchant_grouped.reset_index(),
                                                 on='card_id').merge(train_df,on='card_id',how='right')

# %%
train_df_feats.head()
# Out:
#            card_id  hist_transactions_count  hist_most_frequent_merchant_cat  \
# 0  C_ID_00007093c1                    149.0                            307.0
# 1  C_ID_0001506ef0                     66.0                            705.0
# 2  C_ID_000183fdda                    144.0                            367.0
# 3  C_ID_0002c7c2c1                     67.0                            178.0
# 4  C_ID_0003be3c83                    171.0                            705.0
#
#    hist_most_frequent_subsector  hist_most_frequent_city  \
# 0                          19.0                    244.0
# 1                          33.0                    137.0
# 2                          16.0                    161.0
# 3                          27.0                     69.0
# 4                          37.0                    279.0
#
#    hist_most_frequent_state  hist_min_month_lag  hist_max_purchase_amount  \
# 0                       2.0               -12.0                  1.507069
# 1                      19.0               -13.0                  1.493545
# 2                       3.0                -6.0                  2.764788
# 3                       9.0                -9.0                 -0.296112
# 4                       9.0                -6.0                  1.134802
#
#    new_transactions_count  new_most_frequent_merchant_cat  \
# 0                     2.0                           222.0
# 1                     2.0                           360.0
# 2                    11.0                           367.0
# 3                     6.0                           108.0
# 4                     6.0                            78.0
#
#    new_most_frequent_subsector  new_most_frequent_city  \
# 0                         21.0                    69.0
# 1                         33.0                   137.0
# 2                         16.0                   161.0
# 3                         27.0                   188.0
# 4                         29.0                   279.0
#
#    new_most_frequent_state  new_min_month_lag  new_max_purchase_amount  \
# 0                      2.0                2.0                -0.656749
# 1                     19.0                1.0                -0.715352
# 2                      3.0                1.0                -0.107680
# 3                      9.0                1.0                -0.497768
# 4                      9.0                1.0                -0.167936
#
#   first_active_month  feature_1  feature_2  feature_3    target
# 0         2017-02-01          5          1          1  0.134077
# 1         2016-07-01          2          2          0  0.884295
# 2         2017-09-01          4          1          0 -0.264433
# 3         2017-04-01          3          2          1  1.288514
# 4         2017-08-01          2          3          0 -0.083268

# %%
len(train_df_feats)
# Out:
# 201917

# %%
train_df_feats.columns
# Out:
# Index(['card_id', 'hist_transactions_count', 'hist_most_frequent_merchant_cat',
#        'hist_most_frequent_subsector', 'hist_most_frequent_city',
#        'hist_most_frequent_state', 'hist_min_month_lag',
#        'hist_max_purchase_amount', 'new_transactions_count',
#        'new_most_frequent_merchant_cat', 'new_most_frequent_subsector',
#        'new_most_frequent_city', 'new_most_frequent_state',
#        'new_min_month_lag', 'new_max_purchase_amount', 'first_active_month',
#        'feature_1', 'feature_2', 'feature_3', 'target'],
#       dtype='object')

# %%
transform = [col for col in train_df_feats.columns if 'most' in col]

# %%
len(train_df_feats) - train_df_feats.count()
# Out:
# card_id                                0
# hist_transactions_count            21931
# hist_most_frequent_merchant_cat    21931
# hist_most_frequent_subsector       21931
# hist_most_frequent_city            21931
# hist_most_frequent_state           21931
# hist_min_month_lag                 21931
# hist_max_purchase_amount           21931
# new_transactions_count             21931
# new_most_frequent_merchant_cat     21931
# new_most_frequent_subsector        21931
# new_most_frequent_city             21931
# new_most_frequent_state            21931
# new_min_month_lag                  21931
# new_max_purchase_amount            21931
# first_active_month                     0
# feature_1                              0
# feature_2                              0
# feature_3                              0
# target                                 0
# dtype: int64

# %%
len(train_df_feats)
# Out:
# 201917

# %%
train_df_feats.dropna(inplace=True)

# %%
len(train_df_feats)
# Out:
# 179986

# %%
for col in transform:
    train_df_feats[col] = train_df_feats[col].map(lambda x: np.int(x))

# %%
# transform the first_activ_month feature in : number of months until 01.01.2019
import datetime as dt

reference_date = dt.datetime.strptime('Jan 1 2019', '%b %d %Y').date()
def months_between_dates(date2):
    return reference_date.month - date2.month + 12*(reference_date.year - date2.year)

# %%
train_df_feats['first_active_month'] = train_df_feats['first_active_month'].map(months_between_dates)

# %%
train_df_feats.set_index('card_id',inplace=True)

# %%
categorical = transform + ['feature_1', 'feature_2', 'feature_3']

# %%
train_df_feats.head(5)
# Out:
#                  hist_transactions_count  hist_most_frequent_merchant_cat  \
# card_id
# C_ID_00007093c1                    149.0                              307
# C_ID_0001506ef0                     66.0                              705
# C_ID_000183fdda                    144.0                              367
# C_ID_0002c7c2c1                     67.0                              178
# C_ID_0003be3c83                    171.0                              705
#
#                  hist_most_frequent_subsector  hist_most_frequent_city  \
# card_id
# C_ID_00007093c1                            19                      244
# C_ID_0001506ef0                            33                      137
# C_ID_000183fdda                            16                      161
# C_ID_0002c7c2c1                            27                       69
# C_ID_0003be3c83                            37                      279
#
#                  hist_most_frequent_state  hist_min_month_lag  \
# card_id
# C_ID_00007093c1                         2               -12.0
# C_ID_0001506ef0                        19               -13.0
# C_ID_000183fdda                         3                -6.0
# C_ID_0002c7c2c1                         9                -9.0
# C_ID_0003be3c83                         9                -6.0
#
#                  hist_max_purchase_amount  new_transactions_count  \
# card_id
# C_ID_00007093c1                  1.507069                     2.0
# C_ID_0001506ef0                  1.493545                     2.0
# C_ID_000183fdda                  2.764788                    11.0
# C_ID_0002c7c2c1                 -0.296112                     6.0
# C_ID_0003be3c83                  1.134802                     6.0
#
#                  new_most_frequent_merchant_cat  new_most_frequent_subsector  \
# card_id
# C_ID_00007093c1                             222                           21
# C_ID_0001506ef0                             360                           33
# C_ID_000183fdda                             367                           16
# C_ID_0002c7c2c1                             108                           27
# C_ID_0003be3c83                              78                           29
#
#                  new_most_frequent_city  new_most_frequent_state  \
# card_id
# C_ID_00007093c1                      69                        2
# C_ID_0001506ef0                     137                       19
# C_ID_000183fdda                     161                        3
# C_ID_0002c7c2c1                     188                        9
# C_ID_0003be3c83                     279                        9
#
#                  new_min_month_lag  new_max_purchase_amount  \
# card_id
# C_ID_00007093c1                2.0                -0.656749
# C_ID_0001506ef0                1.0                -0.715352
# C_ID_000183fdda                1.0                -0.107680
# C_ID_0002c7c2c1                1.0                -0.497768
# C_ID_0003be3c83                1.0                -0.167936
#
#                  first_active_month  feature_1  feature_2  feature_3    target
# card_id
# C_ID_00007093c1                  23          5          1          1  0.134077
# C_ID_0001506ef0                  30          2          2          0  0.884295
# C_ID_000183fdda                  16          4          1          0 -0.264433
# C_ID_0002c7c2c1                  21          3          2          1  1.288514
# C_ID_0003be3c83                  17          2          3          0 -0.083268

# %%
import copy
# used : https://stackoverflow.com/questions/18016495/get-subset-of-most-frequent-dummy-variables-in-pandas
# func that returns a dummified DataFrame of significant dummies in a given column
def dum_sign(dummy_col, threshold=0.1):

    # removes the bind
    dummy_col = copy.copy(dummy_col)

    # what is the ratio of a dummy in whole column
    count = pd.value_counts(dummy_col) / len(dummy_col)

    # cond whether the ratios is higher than the threshold
    mask = dummy_col.isin(count[count > threshold].index)

    # replace the ones which ratio is lower than the threshold by a special name
    dummy_col[~mask] = "others"

    return pd.get_dummies(dummy_col, prefix=dummy_col.name)

# %%
print(train_df_feats.shape)
aux_df = train_df_feats.copy() # makes a deep copy of the df
aux_df.head()

for i in range(0, (train_df_feats.shape[1] - 1)):
    aux_df = aux_df.join(dum_sign(train_df_feats.iloc[:,i]))
    
print(aux_df.shape)
aux_df.head()

train_df_feats = aux_df
# Out:
# (179986, 63)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-abff718a0209> in <module>()
#       4
#       5 for i in range(0, (train_df_feats.shape[1] - 1)):
# ----> 6     aux_df = aux_df.join(dum_sign(train_df_feats.iloc[:,i]))
#       7
#       8 print(aux_df.shape)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    6334         # For SparseDataFrame's benefit
#    6335         return self._join_compat(other, on=on, how=how, lsuffix=lsuffix,
# -> 6336                                  rsuffix=rsuffix, sort=sort)
#    6337
#    6338     def _join_compat(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    6349             return merge(self, other, left_on=on, how=how,
#    6350                          left_index=on is None, right_index=True,
# -> 6351                          suffixes=(lsuffix, rsuffix), sort=sort)
#    6352         else:
#    6353             if on is not None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      60                          copy=copy, indicator=indicator,
#      61                          validate=validate)
# ---> 62     return op.get_result()
#      63
#      64
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     572
#     573         llabels, rlabels = items_overlap_with_suffix(ldata.items, lsuf,
# --> 574                                                      rdata.items, rsuf)
#     575
#     576         lindexers = {1: left_indexer} if left_indexer is not None else {}
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in items_overlap_with_suffix(left, lsuffix, right, rsuffix)
#    5242         if not lsuffix and not rsuffix:
#    5243             raise ValueError('columns overlap but no suffix specified: '
# -> 5244                              '{rename}'.format(rename=to_rename))
#    5245
#    5246         def lrenamer(x):
#
# ValueError: columns overlap but no suffix specified: Index(['hist_transactions_count_others'], dtype='object')

# %%
print(train_df_feats.head())
# Out:
#                  hist_transactions_count  hist_most_frequent_merchant_cat  \
# card_id
# C_ID_00007093c1                    149.0                              307
# C_ID_0001506ef0                     66.0                              705
# C_ID_000183fdda                    144.0                              367
# C_ID_0002c7c2c1                     67.0                              178
# C_ID_0003be3c83                    171.0                              705
#
#                  hist_most_frequent_subsector  hist_most_frequent_city  \
# card_id
# C_ID_00007093c1                            19                      244
# C_ID_0001506ef0                            33                      137
# C_ID_000183fdda                            16                      161
# C_ID_0002c7c2c1                            27                       69
# C_ID_0003be3c83                            37                      279
#
#                  hist_most_frequent_state  hist_min_month_lag  \
# card_id
# C_ID_00007093c1                         2               -12.0
# C_ID_0001506ef0                        19               -13.0
# C_ID_000183fdda                         3                -6.0
# C_ID_0002c7c2c1                         9                -9.0
# C_ID_0003be3c83                         9                -6.0
#
#                  hist_max_purchase_amount  new_transactions_count  \
# card_id
# C_ID_00007093c1                  1.507069                     2.0
# C_ID_0001506ef0                  1.493545                     2.0
# C_ID_000183fdda                  2.764788                    11.0
# C_ID_0002c7c2c1                 -0.296112                     6.0
# C_ID_0003be3c83                  1.134802                     6.0
#
#                  new_most_frequent_merchant_cat  new_most_frequent_subsector  \
# card_id
# C_ID_00007093c1                             222                           21
# C_ID_0001506ef0                             360                           33
# C_ID_000183fdda                             367                           16
# C_ID_0002c7c2c1                             108                           27
# C_ID_0003be3c83                              78                           29
#
#                     ...       first_active_month_others  feature_1_2  \
# card_id             ...
# C_ID_00007093c1     ...                               1            0
# C_ID_0001506ef0     ...                               1            1
# C_ID_000183fdda     ...                               1            0
# C_ID_0002c7c2c1     ...                               1            0
# C_ID_0003be3c83     ...                               1            1
#
#                  feature_1_3  feature_1_5  feature_1_others  feature_2_1  \
# card_id
# C_ID_00007093c1            0            1                 0            1
# C_ID_0001506ef0            0            0                 0            0
# C_ID_000183fdda            0            0                 1            1
# C_ID_0002c7c2c1            1            0                 0            0
# C_ID_0003be3c83            0            0                 0            0
#
#                  feature_2_2  feature_2_3  feature_3_0  feature_3_1
# card_id
# C_ID_00007093c1            0            0            0            1
# C_ID_0001506ef0            1            0            1            0
# C_ID_000183fdda            0            0            1            0
# C_ID_0002c7c2c1            1            0            0            1
# C_ID_0003be3c83            0            1            1            0
#
# [5 rows x 63 columns]

# %%
rest_df, val_df_feats = train_test_split(train_df_feats, test_size=0.2, random_state=23)

train_df_feats_final, dev_df_feats = train_test_split(rest_df, test_size=0.2, random_state=23)

# %%
print('length of training set: ', len(train_df_feats_final))
print('length of validation set: ', len(val_df_feats))
print('length of development set: ', len(dev_df_feats))
print('sum of the above: ',len(train_df_feats_final) + len(val_df_feats) + len(dev_df_feats))
print('length of previous trainingset: ',len(train_df))
# Out:
# length of training set:  115190
# length of validation set:  35998
# length of development set:  28798
# sum of the above:  179986
# length of previous trainingset:  201917

# %%
train_df_feats_final.to_csv(os.path.join('data','train_feats.csv'),index=False)
val_df_feats.to_csv(os.path.join('data','val_feats.csv'),index=False)
dev_df_feats.to_csv(os.path.join('data','dev_feats.csv'),index=False)

# %%
test_df.head()
# Out:
#   first_active_month          card_id  feature_1  feature_2  feature_3
# 0         2017-04-01  C_ID_0ab67a22ab          3          3          1
# 1         2017-01-01  C_ID_130fd0cbdd          2          3          0
# 2         2017-08-01  C_ID_b709037bc5          5          1          1
# 3         2017-12-01  C_ID_d27d835a9f          2          1          0
# 4         2015-12-01  C_ID_2b5e3df5c2          5          1          1

# %%
len(test_df)
# Out:
# 123623

# %% [markdown]
# merge the hist and new merchants features to the train_df

# %%
test_df_feats = hist_grouped.reset_index().merge(new_merchant_grouped.reset_index(),
                                                 on='card_id').merge(test_df,on='card_id',how='right')

# %%
test_df_feats.head()
# Out:
#            card_id  hist_transactions_count  hist_most_frequent_merchant_cat  \
# 0  C_ID_0001238066                    123.0                            307.0
# 1  C_ID_0001793786                    216.0                            278.0
# 2  C_ID_0002709b5a                     73.0                            705.0
# 3  C_ID_000298032a                     30.0                            560.0
# 4  C_ID_0002ba3c2e                     70.0                            705.0
#
#    hist_most_frequent_subsector  hist_most_frequent_city  \
# 0                          19.0                    314.0
# 1                          37.0                    179.0
# 2                          33.0                    103.0
# 3                          34.0                    233.0
# 4                          33.0                    344.0
#
#    hist_most_frequent_state  hist_min_month_lag  hist_max_purchase_amount  \
# 0                       9.0                -5.0                  0.768095
# 1                      -1.0                -9.0                  4.554145
# 2                      18.0               -13.0                 -0.336684
# 3                       9.0               -11.0                  2.577843
# 4                      18.0                -9.0                 -0.097011
#
#    new_transactions_count  new_most_frequent_merchant_cat  \
# 0                    26.0                           278.0
# 1                    31.0                           278.0
# 2                     3.0                           605.0
# 3                     1.0                           432.0
# 4                     3.0                           705.0
#
#    new_most_frequent_subsector  new_most_frequent_city  \
# 0                         37.0                   314.0
# 1                         37.0                    69.0
# 2                          2.0                    69.0
# 3                         27.0                    23.0
# 4                         33.0                   344.0
#
#    new_most_frequent_state  new_min_month_lag  new_max_purchase_amount  \
# 0                      9.0                1.0                -0.078318
# 1                      9.0                1.0                 3.129932
# 2                      9.0                1.0                -0.611669
# 3                      9.0                2.0                -0.641872
# 4                     18.0                1.0                -0.667883
#
#   first_active_month  feature_1  feature_2  feature_3
# 0         2017-09-01          4          1          0
# 1         2017-01-01          5          2          1
# 2         2015-08-01          5          1          1
# 3         2016-12-01          2          2          0
# 4         2016-06-01          5          2          1

# %%
print(len(test_df_feats))
print(test_df_feats.shape)
# Out:
# 123623
# (123623, 19)

# %%
test_df_feats["first_active_month"] = test_df_feats["first_active_month"].map(months_between_dates) 
test_df_feats.set_index('card_id',inplace=True)

# %%
temp_df = test_df_feats.copy()

for i in range(0, (test_df_feats.shape[1]-1)):
    temp_df = temp_df.join(dum_sign(test_df_feats.iloc[:, i]))
    
print(temp_df.shape)
temp_df.head()

test_df_feats = temp_df
# Out:
# (123623, 59)

# %%
#see how many NaN values we have
test_df_feats.isna().sum()

# we replace those NaN values with the mode
#for i in range (0, test_df_feats.shape[1]-1):
   # test_df_feats.iloc[:,i] = test_df_feats.iloc[:,i].fillna(test_df_feats.iloc[:,i].value_counts().idxmax())
    
# we replace those NaN values with the 0
for i in range (0, test_df_feats.shape[1]-1):
    test_df_feats.iloc[:,i] = test_df_feats.iloc[:,i].fillna(0)

# %%
#double check
test_df_feats.isna().sum()
# Out:
# hist_transactions_count                   0
# hist_most_frequent_merchant_cat           0
# hist_most_frequent_subsector              0
# hist_most_frequent_city                   0
# hist_most_frequent_state                  0
# hist_min_month_lag                        0
# hist_max_purchase_amount                  0
# new_transactions_count                    0
# new_most_frequent_merchant_cat            0
# new_most_frequent_subsector               0
# new_most_frequent_city                    0
# new_most_frequent_state                   0
# new_min_month_lag                         0
# new_max_purchase_amount                   0
# first_active_month                        0
# feature_1                                 0
# feature_2                                 0
# feature_3                                 0
# hist_transactions_count_others            0
# hist_most_frequent_merchant_cat_307.0     0
# hist_most_frequent_merchant_cat_705.0     0
# hist_most_frequent_merchant_cat_others    0
# hist_most_frequent_subsector_19.0         0
# hist_most_frequent_subsector_33.0         0
# hist_most_frequent_subsector_37.0         0
# hist_most_frequent_subsector_others       0
# hist_most_frequent_city_69.0              0
# hist_most_frequent_city_others            0
# hist_most_frequent_state_9.0              0
# hist_most_frequent_state_others           0
# hist_min_month_lag_-13.0                  0
# hist_min_month_lag_others                 0
# hist_max_purchase_amount_others           0
# new_transactions_count_1.0                0
# new_transactions_count_2.0                0
# new_transactions_count_others             0
# new_most_frequent_merchant_cat_80.0       0
# new_most_frequent_merchant_cat_307.0      0
# new_most_frequent_merchant_cat_others     0
# new_most_frequent_subsector_19.0          0
# new_most_frequent_subsector_27.0          0
# new_most_frequent_subsector_37.0          0
# new_most_frequent_subsector_others        0
# new_most_frequent_city_69.0               0
# new_most_frequent_city_others             0
# new_most_frequent_state_9.0               0
# new_most_frequent_state_others            0
# new_min_month_lag_1.0                     0
# new_min_month_lag_2.0                     0
# new_min_month_lag_others                  0
# new_max_purchase_amount_others            0
# first_active_month_others                 0
# feature_1_2                               0
# feature_1_3                               0
# feature_1_5                               0
# feature_1_others                          0
# feature_2_1                               0
# feature_2_2                               0
# feature_2_3                               0
# dtype: int64

# %%
test_df_feats.to_csv(os.path.join('data','test_feats.csv'),index=False)
